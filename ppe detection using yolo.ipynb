# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.5/870.5 kB 46.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 198.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="T8bmtUPgQjpkXG1XBkdW")
project = rf.workspace("project-uyrxf").project("ppe_detection-v1x3l")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# '/teamspace/studios/this_studio/PPE_Detection-2'

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model="yolo11n.pt" epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.13 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA A10G, 22724MiB)
# ...

# %%
Image('/teamspace/studios/this_studio/runs/detect/train3/labels.jpg',width=600)

# %%
Image('/teamspace/studios/this_studio/runs/detect/train3/results.png',width=600)

# %%
# !yolo task=detect mode=predict model="runs/detect/train3/weights/best.pt" conf=0.25 source='/teamspace/studios/this_studio/Take Time to Take Care (Machine Safety).mp4' save=True
# Out:
# Ultralytics 8.3.13 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA A10G, 22724MiB)
# YOLO11n summary (fused): 238 layers, 2,583,517 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/1 (frame 1/1500) /teamspace/studios/this_studio/Take Time to Take Care (Machine Safety).mp4: 384x640 1 Protective Helmet, 2 Safety Vests, 134.6ms
# video 1/1 (frame 2/1500) /teamspace/studios/this_studio/Take Time to Take Care (Machine Safety).mp4: 384x640 1 Protective Helmet, 2 Safety Vests, 8.2ms
# video 1/1 (frame 3/1500) /teamspace/studios/this_studio/Take Time to Take Care (Machine Safety).mp4: 384x640 1 Protective Helmet, 2 Safety Vests, 8.1ms
# video 1/1 (frame 4/1500) /teamspace/studios/this_studio/Take Time to Take Care (Machine Safety).mp4: 384x640 1 Protective Helmet, 3 Safety Vests, 8.0ms
# video 1/1 (frame 5/1500) /teamspace/studios/this_studio/Take Time to Take Care (Machine Safety).mp4: 384x640 3 Safety Vests, 8.0ms
# ...

# %%
# !pip install ffmpeg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=2304a3294fa49c278ce2deab2bc4b3aefe4f3ee7d6773e1034e92ea93547a569
#   Stored in directory: /home/zeus/.cache/pip/wheels/8e/7a/69/cd6aeb83b126a7f04cbe7c9d929028dc52a6e7d525ff56003a
# Successfully built ffmpeg
# ...
